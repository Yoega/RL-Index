# %%
import pandas as pd

# %%
path = f"v2_train.parquet"
data_df = pd.read_parquet(path)
print(data_df.columns)
# Out:
# Index(['query', 'pos'], dtype='str')

# %%
data_df
# Out:
#                                                    query  \
# 0      \nI'm new to the artificial intelligence field...
# 1      \nSince a neutron and a proton are made up of ...
# 2      \nTo extend from the question things like goog...
# 3      \nI want to test the hypothesis that a group o...
# 4      \nDarwin suggested that sexual selection, espe...
# ...                                                  ...
# 30869  \nIf I understand it right, correct term for s...
# 30870  \nGood day\nI am currently implementing an aut...
# 30871  \nHow can I convert a sequence provided in a M...
# 30872  \nI have just started thinking about probabili...
# 30873  \nWhich of these two theories is more accepted...
#
#                                                      pos
# 0      This is a fundamentally a philosophical questi...
# 1      A neutron is made of 3 quarks, two up quarks a...
# 2      Because not all programs require for their ope...
# ...
